# %%
import requests
import pandas as pd
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.common.exceptions import NoSuchElementException
import time

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None
    """
    try:
        with closing(requests.get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None
    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# %%
def is_good_response(resp):
    """
    Returns true if the response seems to be HTML, false otherwise
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

# %%
def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
def getCategory():
    category = []
    text = []

    page1 = simple_get('https://www.indotrading.com/productcatalog/')
    soup1 = BeautifulSoup(page1, 'html.parser')
    findCategory = soup1.find_all('div', class_='idt-head-catalog cat-product')

    for a in findCategory:
        href = a.find('a', class_='span-bold clr-red line-clamp-2', href=True)
        category.append(href['href'])
        text.append(href.text)
        
    return category,text

# %%
def filterLinkProvince(category):
    province = []
    checked = True
    
    categoryPage = simple_get(category+ '/perusahaan')
    while(checked):
        try:
            checked = False
            soup2 = BeautifulSoup(categoryPage, 'html.parser')
            divProv = soup2.find('div', class_='filkat-sub')
            temp = divProv.find_all('a', href=True)
        except Exception:
            checked = True

    for a in temp:

        province.append(a['href'])
    
    
    return province

# %%
def filterTextProvince(category):
    textProv = []
    
    categoryPage = simple_get(category + '/perusahaan')
    soup2 = BeautifulSoup(categoryPage, 'html.parser')
    divProv = soup2.find('div', class_='filkat-sub')
    temp = divProv.find_all('a', href=True)

    for a in temp:

        textProv.append(a.text)
    
    return textProv

# %%
def getLinkCompany(province):
    
    linkCompany = []
    checked = True
    
    for page in range(1,10):
        
        if page == 1:
            url = province
        else:
            url = province + '?page=' + str(page)
    
        try:
            perusahaanPage = simple_get(url)
            soup3 = BeautifulSoup(perusahaanPage, 'html.parser')
            listCompany = soup3.find_all('div', class_='list-item-company')
        except Exception:
            try:
                perusahaanPage = simple_get(url)
                soup3 = BeautifulSoup(perusahaanPage, 'html.parser')
                listCompany = soup3.find_all('div', class_='list-item-company')
            except Exception:
                try:
                    perusahaanPage = simple_get(url)
                    soup3 = BeautifulSoup(perusahaanPage, 'html.parser')
                    listCompany = soup3.find_all('div', class_='list-item-company')
                except Exception:
                    print('error')
                    continue

        for i in listCompany:
            productInfo = i.find('a', class_='link_product')
            if productInfo == None:
                continue
            else :
                linkCompany.append('https:'+ productInfo['href'])

    return linkCompany

# %%
def getLinkWhatsapp(url):
    
    linkWa = []
    
    driver = webdriver.Chrome('C:/Users/Swift3/Downloads/Scrapper/path/chromedriver')
    driver.get(url)
    try:
        driver.find_element_by_class_name('wa-call').click()
    except NoSuchElementException as exception:
        return None
   
    time.sleep(3)
    page_source = driver.page_source
    soup4 = BeautifulSoup(page_source, 'html.parser').find_all('a', class_='nobor')
    for i in soup4:
        linkWa.append(i['href'])
    
    return linkWa

# %%
def getPhoneWA(url):
    try:
        whatsapp = simple_get(url)
        soup1 = BeautifulSoup(whatsapp, 'html.parser')
        findNumber = soup1.find('span', class_='').text
    except Exception:
        try:
            whatsapp = simple_get(url)
            soup1 = BeautifulSoup(whatsapp, 'html.parser')
            findNumber = soup1.find('span', class_='').text
        except Exception:
            try:
                whatsapp = simple_get(url)
                soup1 = BeautifulSoup(whatsapp, 'html.parser')
                findNumber = soup1.find('span', class_='').text
            except Exception:
                try:
                    whatsapp = simple_get(url)
                    soup1 = BeautifulSoup(whatsapp, 'html.parser')
                    findNumber = soup1.find('span', class_='').text
                except Exception:
                    return None
    
    return findNumber

# %%
companyProfile = {
    'Name':'',
    'City':'',
    'Province':'',
    'Phone WA':''
}

# %%
category = getCategory()

# %%
listLink=[]
for item in category[0]:
    content = simple_get(item)
    soup = BeautifulSoup(content, 'html.parser')
    list_company = soup.find('a', class_='idt-elipsis')
    listLink.append(list_company['href'])
# Out:
# https://www.indotrading.com/company_jual-ac-industri-dan-perangkatnya_7705/
# https://www.indotrading.com/company_jual-adaptor-saklar-dan-socket_7718/
# https://www.indotrading.com/company_jual-aksesoris-genset_15308/
# https://www.indotrading.com/company_aksesoriskabel_150/
# https://www.indotrading.com/company_peralatanperlengkapanlistrik_867/
# https://www.indotrading.com/company_jual-alat-pemanas_19769/
# https://www.indotrading.com/company_alat-pengendali-industri_12717/
# https://www.indotrading.com/company_jual-tenaga-surya-dan-energi-terbarukan_7692/
# https://www.indotrading.com/company_baterai_132/
# https://www.indotrading.com/company_produkcctv_667/
# https://www.indotrading.com/company_pemutusrangkaian_138/
# https://www.indotrading.com/company_jual-dinamo-motor_19754/
# https://www.indotrading.com/company_jual-led-display-dan-sign-board_7721/
# https://www.indotrading.com/company_home-appliances_4881/
# https://www.indotrading.com/company_genset_141/
# https://www.indotrading.com/company_gpsdannavigasi_130/
# https://www.indotrading.com/company_kabel_137/
# https://www.indotrading.com/company_fotografi_766/
# https://www.indotrading.com/company_komponenelektronik_854/
# https://www.indotrading.com/company_konduitkabel_152/
# https://www.indotrading.com/company_jual-konektor-kabel_7188/
# https://www.indotrading.com/company_media-player_4844/
# https://www.indotrading.com/company_jual-panel-listrik-dan-distribution-box_7724/
# https://www.indotrading.com/company_pendinginruangan_407/
# https://www.indotrading.com/company_audio_4845/
# https://www.indotrading.com/company_jual-peralatan-elektronik-kantor_7727/
# https://www.indotrading.com/company_powersupply_720/
# https://www.indotrading.com/company_jual-resistor-dan-perangkat-pasif_7725/
# https://www.indotrading.com/company_jual-sensor-dan-transducer_7782/
# https://www.indotrading.com/company_sistem-dan-produk-akses-kontrol_4916/
# https://www.indotrading.com/company_sukucadangacdanpendingin_777/
# https://www.indotrading.com/company_trafo_136/
# https://www.indotrading.com/company_televisi_125/
# https://www.indotrading.com/company_jual-voltage-dan-power-stabilizer_7716/
# https://www.indotrading.com/company_jual-komponen-pintu-jendela_7676/
# https://www.indotrading.com/company_jual-alat-klem_7682/
# https://www.indotrading.com/company_atap_296/
# https://www.indotrading.com/company_materialbangunan_286/
# https://www.indotrading.com/company_bathtub_264/
# https://www.indotrading.com/company_batu_251/
# https://www.indotrading.com/company_jual-bracket_18455/
# https://www.indotrading.com/company_catdanpelapis_289/
# https://www.indotrading.com/company_jual-cladding-panel-dinding_7712/
# https://www.indotrading.com/company_closet_269/
# https://www.indotrading.com/company_jual-alat-drainase_7224/
# https://www.indotrading.com/company_jual-flange_6002/
# https://www.indotrading.com/company_genteng_1961/
# https://www.indotrading.com/company_jual-geosintetik_18185/
# https://www.indotrading.com/company_jembatan-apung_4049/
# https://www.indotrading.com/company_jendela_283/
# https://www.indotrading.com/company_kayu_703/
# https://www.indotrading.com/company_konstruksi-besi_4850/
# https://www.indotrading.com/company_jual-kran-air_6244/
# https://www.indotrading.com/company_lantaidanaksesori_243/
# https://www.indotrading.com/company_pagarteralisgerbang_847/
# https://www.indotrading.com/company_jual-peredam-suara_13151/
# https://www.indotrading.com/company_jual-perlengkapan-bangunan_7146/
# https://www.indotrading.com/company_kamarmandidandapur_259/
# https://www.indotrading.com/company_jual-perlengkapan-ruang-dapur_7254/
# https://www.indotrading.com/company_doors_278/
# https://www.indotrading.com/company_pipa_4257/
# https://www.indotrading.com/company_plafon_3536/
# https://www.indotrading.com/company_jual-rantai_18113/
# https://www.indotrading.com/company_jual-sambungan-pipa_7713/
# https://www.indotrading.com/company_alatdeteksikebocoran_2588/
# https://www.indotrading.com/company_alatlaboratorium_705/
# https://www.indotrading.com/company_peralatansurvey_852/
# https://www.indotrading.com/company_jual-alat-uji-listrik-dan-elektronik_7953/
# https://www.indotrading.com/company_jual-alat-uji-tanah_5928/
# https://www.indotrading.com/company_jual-alat-ukur-dan-instrumen_7779/
# https://www.indotrading.com/company_jual-alat-ukur-kemiringan_7455/
# https://www.indotrading.com/company_alat-ukur-suhu_4480/
# https://www.indotrading.com/company_pengukurtekanan_662/
# https://www.indotrading.com/company_analyzers_648/
# https://www.indotrading.com/company_jual-kalibrasi-dan-sistem-pemantauan_7801/
# https://www.indotrading.com/company_pengukuraliran_1113/
# https://www.indotrading.com/company_pengukurcahaya_1112/
# https://www.indotrading.com/company_pengukurelektronik_1105/
# https://www.indotrading.com/company_pengukurjarak_1167/
# https://www.indotrading.com/company_pengukurkecepatan_1109/
# https://www.indotrading.com/company_pengukurkelembaban_651/
# https://www.indotrading.com/company_pengukurlevel_695/
# https://www.indotrading.com/company_pengukurlistrik_649/
# https://www.indotrading.com/company_pengukur-permukaan_4852/
# https://www.indotrading.com/company_pengukur-suara_4851/
# https://www.indotrading.com/company_jual-peralatan-cuaca-dan-meteorologi_7799/
# https://www.indotrading.com/company_peralatanoptikdanlaser_853/
# https://www.indotrading.com/company_pengukurberat_660/
# https://www.indotrading.com/company_timers_663/
# https://www.indotrading.com/company_alatalatjahit_229/
# https://www.indotrading.com/company_boiler_739/
# https://www.indotrading.com/company_evaporator_4345/
# https://www.indotrading.com/company_hidrolik_736/
# https://www.indotrading.com/company_jual-mesin-bending-press_7761/
# https://www.indotrading.com/company_mesinbesi_584/
# https://www.indotrading.com/company_jual-mesin-bor_155/
# https://www.indotrading.com/company_mesincetak_582/
# https://www.indotrading.com/company_mesinindustri_609/
# https://www.indotrading.com/company_mesinkimiafarmasi_819/
# https://www.indotrading.com/company_jual-mesin-kimia_7980/
# https://www.indotrading.com/company_jual-mesin-jahit_3092/
# https://www.indotrading.com/company_mesinkayu_605/
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# https://www.indotrading.com/company_jual-mesin-las_737/
# https://www.indotrading.com/company_mesinmakanan_580/
# https://www.indotrading.com/company_mesinmaterial_698/
# https://www.indotrading.com/company_mesinminuman_666/
# https://www.indotrading.com/company_jual-pengaduk-homogenizer_7742/
# https://www.indotrading.com/company_jual-mesin-moulding_7743/
# https://www.indotrading.com/company_mesinpackaging_581/
# https://www.indotrading.com/company_mesinpembersihlantai_1267/
# https://www.indotrading.com/company_jual-mesin-pembuat-es_3462/
# https://www.indotrading.com/company_mesinpemotong_2824/
# https://www.indotrading.com/company_jual-mesin-penanganan-polusi_7983/
# https://www.indotrading.com/company_mesinpengolahkacangbiji_1235/
# https://www.indotrading.com/company_jual-mesin-produksi-karet-ban_7764/
# https://www.indotrading.com/company_jual-mesin-tambang-ekstraksi_7759/
# https://www.indotrading.com/company_mesinkaretplastik_604/
# https://www.indotrading.com/company_jual-mesin-pengupas_13954/
# https://www.indotrading.com/company_mesinperalatanrumah_1272/
# https://www.indotrading.com/company_mesinperkebunan_607/
# https://www.indotrading.com/company_mesinpertanian_606/
# https://www.indotrading.com/company_mesin-press_1948/
# https://www.indotrading.com/company_jual-mesin-sirkulasi-pendingin_7765/
# https://www.indotrading.com/company_mesintekstil_824/
# https://www.indotrading.com/company_jual-peralatan-cat_7701/
# https://www.indotrading.com/company_peralatan-pengeboran_2457/
# https://www.indotrading.com/company_sukucadangmesin_2855/
# https://www.indotrading.com/company_jual-tangki-reaktor-kimia_7734/
# https://www.indotrading.com/company_jual-turbin_18306/
# https://www.indotrading.com/company_watertreatment_424/
# https://www.indotrading.com/company_jual-alat-stempel_17006/
# https://www.indotrading.com/company_jual-conveyor_19821/
# https://www.indotrading.com/company_jual-filter_5881/
# https://www.indotrading.com/company_box-container_2951/
# https://www.indotrading.com/company_materialpenahanpanas_702/
# https://www.indotrading.com/company_olidanpelumas_317/
# https://www.indotrading.com/company_palet_1226/
# https://www.indotrading.com/company_jual-perlengkapan-las_7729/
# https://www.indotrading.com/company_pompa-dan-perlengkapannya_4923/
# https://www.indotrading.com/company_jual-selang_20711/
# https://www.indotrading.com/company_sistemrak_883/
# https://www.indotrading.com/company_jual-troli_19827/
# https://www.indotrading.com/company_alatpemadamkebakaran_487/
# https://www.indotrading.com/company_alatsafety_675/
# https://www.indotrading.com/company_alat-sekuriti-dan-keamanan_4918/
# https://www.indotrading.com/company_keamananjalankendaraan_1402/
# https://www.indotrading.com/company_segelkeamanan_3145/
# https://www.indotrading.com/company_water-safety_4917/
# https://www.indotrading.com/company_bearing_729/
# https://www.indotrading.com/company_beltmesin_3533/
# https://www.indotrading.com/company_gasket_732/
# https://www.indotrading.com/company_jual-gland-packing_5742/
# https://www.indotrading.com/company_katupvalves_733/
# https://www.indotrading.com/company_mur-baut_1946/
# https://www.indotrading.com/company_gearmotor_3535/
# https://www.indotrading.com/company_silinder_730/
# https://www.indotrading.com/company_aksesorislampu_438/
# https://www.indotrading.com/company_lampu-bohlam-dan-tabung_4878/
# https://www.indotrading.com/company_jual-lampu-hias-dan-pesta_7732/
# https://www.indotrading.com/company_lampugantung_1860/
# https://www.indotrading.com/company_lampuluarruang_444/
# https://www.indotrading.com/company_lampusorot_858/
# https://www.indotrading.com/company_pencahayaan-profesional_4879/
# https://www.indotrading.com/company_senter_450/
# https://www.indotrading.com/company_jual-tiang-lampu_6804/
# https://www.indotrading.com/company_bahanbakukaret_626/
# https://www.indotrading.com/company_bahanbakuplastik_618/
# https://www.indotrading.com/company_busamatras_1991/
# https://www.indotrading.com/company_fiberglass_713/
# https://www.indotrading.com/company_produkkaret_639/
# https://www.indotrading.com/company_produkplastik_631/
# https://www.indotrading.com/company_jual-styrofoam_6197/
# https://www.indotrading.com/company_tali_2048/
# https://www.indotrading.com/company_terpal_1859/
# https://www.indotrading.com/company_bahankimiakosmetik_4195/
# https://www.indotrading.com/company_bahantambahanmakanan_545/
# https://www.indotrading.com/company_bahankimiapertanian_547/
# https://www.indotrading.com/company_bahanpelekat_546/
# https://www.indotrading.com/company_cairanpembersih_1812/
# https://www.indotrading.com/company_jual-katalisator-kimia_7861/
# https://www.indotrading.com/company_kimiaunorganik_549/
# https://www.indotrading.com/company_kimiafarmasi_558/
# https://www.indotrading.com/company_kimia-industri_2504/
# https://www.indotrading.com/company_jual-minyak-bumi-petrokimia_7867/
# https://www.indotrading.com/company_pigmentdanpewarna_559/
# https://www.indotrading.com/company_jual-resin_10470/
# https://www.indotrading.com/company_jual-solvent-pelarut_7871/
# https://www.indotrading.com/company_bahankue_342/
# https://www.indotrading.com/company_bumbu-dapur_4924/
# https://www.indotrading.com/company_jual-frozen-food_18155/
# https://www.indotrading.com/company_gula_335/
# https://www.indotrading.com/company_kuedanmakanankering_747/
# https://www.indotrading.com/company_makananinstan_334/
# https://www.indotrading.com/company_snacks_343/
# https://www.indotrading.com/company_minuman_340/
# https://www.indotrading.com/company_minyaknabatidanhewani_21/
# https://www.indotrading.com/company_jual-sayur-biji-organik_7924/
# https://www.indotrading.com/company_produksusu_26/
# https://www.indotrading.com/company_rasadanpewangi_862/
# https://www.indotrading.com/company_tepung_1862/
# https://www.indotrading.com/company_mesinkonstruksi_583/
# https://www.indotrading.com/company_jual-excavator-mesin-pemindah_7704/
# https://www.indotrading.com/company_jual-mesin-pengangkat_7726/
# https://www.indotrading.com/company_jual-alat-penggali_18132/
# https://www.indotrading.com/company_dongkrak_1963/
# https://www.indotrading.com/company_lift_3557/
# https://www.indotrading.com/company_mesinpemadattanah_1263/
# https://www.indotrading.com/company_jual-spare-part-alat-berat_20098/
# https://www.indotrading.com/company_jual-traktor-dan-suku-cadang_7125/
# https://www.indotrading.com/company_aksesoris-pesta_4897/
# https://www.indotrading.com/company_barangantikdanjimat_775/
# https://www.indotrading.com/company_barangpromosi_114/
# https://www.indotrading.com/company_dekorasi_4896/
# https://www.indotrading.com/company_jual-gift-kerajinan-dan-artefak_7889/
# https://www.indotrading.com/company_kerajinanbambu_101/
# https://www.indotrading.com/company_kerajinanbatu_105/
# https://www.indotrading.com/company_kerajinancrystal_109/
# https://www.indotrading.com/company_kerajinankain_112/
# https://www.indotrading.com/company_jual-kerajinan-keramik-dan-tanah-liat_7898/
# https://www.indotrading.com/company_kerajinankertas_103/
# https://www.indotrading.com/company_kerajinanreligius_113/
# https://www.indotrading.com/company_kerajinansulaman_119/
# https://www.indotrading.com/company_patung_116/
# https://www.indotrading.com/company_piala-medali-dan-plakat_5039/
# https://www.indotrading.com/company_senilukisdankaligrafi_804/
# https://www.indotrading.com/company_perkakas-bengkel_3014/
# https://www.indotrading.com/company_alatalatkerja_154/
# https://www.indotrading.com/company_perabotanak_349/
# https://www.indotrading.com/company_perabotantik_375/
# https://www.indotrading.com/company_perabotbar_1341/
# https://www.indotrading.com/company_perabotbayi_345/
# https://www.indotrading.com/company_perabothotel_367/
# https://www.indotrading.com/company_perabotkamartidur_765/
# https://www.indotrading.com/company_perabotkantor_366/
# https://www.indotrading.com/company_perabotluarruang_364/
# https://www.indotrading.com/company_perabotplastik_1322/
# https://www.indotrading.com/company_perabotrestoran_369/
# https://www.indotrading.com/company_perabotruangkeluarga_358/
# https://www.indotrading.com/company_perabotruangmakan_1352/
# https://www.indotrading.com/company_perabotrumahsakit_368/
# https://www.indotrading.com/company_perabotsekolah_1778/
# https://www.indotrading.com/company_perabotkomersial_365/
# https://www.indotrading.com/company_perangkatperabot_1362/
# https://www.indotrading.com/company_jual-perlengkapan-pameran_7814/
# https://www.indotrading.com/company_produkdanperalatanbayi_778/
# https://www.indotrading.com/company_alatdapur_411/
# https://www.indotrading.com/company_alatlaundry_420/
# https://www.indotrading.com/company_jual-bahan-laundry_18066/
# https://www.indotrading.com/company_dekorasi-rumah_4853/
# https://www.indotrading.com/company_taman_776/
# https://www.indotrading.com/company_kompor_772/
# https://www.indotrading.com/company_pembersihruangan_409/
# https://www.indotrading.com/company_jual-peralatan-kolam-renang_5796/
# https://www.indotrading.com/company_peralatanmakan_4243/
# https://www.indotrading.com/company_peralatan-rumah-tangga_4880/
# https://www.indotrading.com/company_jual-perlengkapan-tidur-bayi_4144/
# https://www.indotrading.com/company_produkhewanpeliharaan_849/
# https://www.indotrading.com/company_tangga_4887/
# https://www.indotrading.com/company_alatkecantikan_431/
# https://www.indotrading.com/company_kertastissue_1156/
# https://www.indotrading.com/company_jual-minyak-astiri-dan-aromatik_7926/
# https://www.indotrading.com/company_perawatankecantikan_784/
# https://www.indotrading.com/company_produkperawatanpribadi_783/
# https://www.indotrading.com/company_aluminium_709/
# https://www.indotrading.com/company_bahannikel_602/
# https://www.indotrading.com/company_bahanstainless_752/
# https://www.indotrading.com/company_besi_707/
# https://www.indotrading.com/company_karbon_711/
# https://www.indotrading.com/company_kawat_603/
# https://www.indotrading.com/company_kuningan_4830/
# https://www.indotrading.com/company_mineralnonlogam_1327/
# https://www.indotrading.com/company_tembaga_712/
# https://www.indotrading.com/company_timah_4831/
# https://www.indotrading.com/company_alatpercetakan_827/
# https://www.indotrading.com/company_botol_5028/
# https://www.indotrading.com/company_layanancetak_388/
# https://www.indotrading.com/company_peralatanpengemasan_793/
# https://www.indotrading.com/company_aksesoris-interior-otomotif_4885/
# https://www.indotrading.com/company_ban_324/
# https://www.indotrading.com/company_body-mobil_2800/
# https://www.indotrading.com/company_sukucadang_321/
# https://www.indotrading.com/company_sukucadangmotor_2836/
# https://www.indotrading.com/company_sukucadangtruk_544/
# https://www.indotrading.com/company_alatpernafasan_4778/
# https://www.indotrading.com/company_jual-alat-diagnosa-medis_7773/
# https://www.indotrading.com/company_alat-kesehatan_4928/
# https://www.indotrading.com/company_jual-alat-sterilisasi-medis_7807/
# https://www.indotrading.com/company_mikroskop_1950/
# https://www.indotrading.com/company_obatobatan_430/
# https://www.indotrading.com/company_peralatanmedis_820/
# https://www.indotrading.com/company_peralatanoperasi_4770/
# https://www.indotrading.com/company_aksesoriskomputer_198/
# https://www.indotrading.com/company_peralatanprinter_451/
# https://www.indotrading.com/company_software_756/
# https://www.indotrading.com/company_komponenkomputer_176/
# https://www.indotrading.com/company_desktopsdanservers_173/
# https://www.indotrading.com/company_mediapenyimpanan_184/
# https://www.indotrading.com/company_networkingdevice_191/
# https://www.indotrading.com/company_printer_755/
# https://www.indotrading.com/company_scanner_467/
# https://www.indotrading.com/company_peralatanperikanan_842/
# https://www.indotrading.com/company_peralatanperkebunan_37/
# https://www.indotrading.com/company_alatpertanian_48/
# https://www.indotrading.com/company_alatpeternakan_1975/
# https://www.indotrading.com/company_beras_19/
# https://www.indotrading.com/company_bibittanaman_7/
# https://www.indotrading.com/company_bijibijian_1371/
# https://www.indotrading.com/company_bungadantanaman_24/
# https://www.indotrading.com/company_jual-hasil-pertanian-perkebunan_7359/
# https://www.indotrading.com/company_jual-hasil-peternakan_7144/
# https://www.indotrading.com/company_jual-ikan-hasil-laut_7452/
# https://www.indotrading.com/company_kacangkacangan_3/
# https://www.indotrading.com/company_madu_31/
# https://www.indotrading.com/company_makananhewanternak_25/
# https://www.indotrading.com/company_produkpestisida_29/
# https://www.indotrading.com/company_pupuk_30/
# https://www.indotrading.com/company_teh_9/
# https://www.indotrading.com/company_umbiumbian_69/
# https://www.indotrading.com/company_aksesoris-pakaian_4899/
# https://www.indotrading.com/company_atasan_4908/
# https://www.indotrading.com/company_bajumuslim_212/
# https://www.indotrading.com/company_baju-terusan_5033/
# https://www.indotrading.com/company_bawahan_4912/
# https://www.indotrading.com/company_gaun_220/
# https://www.indotrading.com/company_outerwear_4911/
# https://www.indotrading.com/company_pakaiananak_208/
# https://www.indotrading.com/company_pakaianbayi_209/
# https://www.indotrading.com/company_pakaiandalam_216/
# https://www.indotrading.com/company_pakaian-khusus_4910/
# https://www.indotrading.com/company_perhiasandanimitasi_236/
# https://www.indotrading.com/company_jual-perlengkapan-sholat_7319/
# https://www.indotrading.com/company_sepatu_233/
# https://www.indotrading.com/company_seragam_217/
# https://www.indotrading.com/company_alattuliskantor_3203/
# https://www.indotrading.com/company_kertas_457/
# https://www.indotrading.com/company_mesin-absensi_4842/
# https://www.indotrading.com/company_board_4931/
# https://www.indotrading.com/company_peralatansekolah_452/
# https://www.indotrading.com/company_jual-perlengkapan-kasir_6390/
# https://www.indotrading.com/company_bahankulit_575/
# https://www.indotrading.com/company_benang_576/
# https://www.indotrading.com/company_tekstil-kebutuhan-rmah_4940/
# https://www.indotrading.com/company_kain_4941/
# https://www.indotrading.com/company_tenda_4855/
# https://www.indotrading.com/company_aksesorissepeda_535/
# https://www.indotrading.com/company_aksesoristruk_543/
# https://www.indotrading.com/company_alat-perkapalan_2447/
# https://www.indotrading.com/company_dealer-otomotif_4914/
# https://www.indotrading.com/company_kapalperahu_836/
# https://www.indotrading.com/company_karoseri_1082/
# https://www.indotrading.com/company_sepeda_534/
# https://www.indotrading.com/company_sukucadangkapal_2833/
# https://www.indotrading.com/company_truk_539/
# https://www.indotrading.com/company_aksesorishandphone_495/
# https://www.indotrading.com/company_antena_498/
# https://www.indotrading.com/company_telepon_496/
# https://www.indotrading.com/company_perlengkapan-komunikasi_4943/
# https://www.indotrading.com/company_alatmusik_1400/
# https://www.indotrading.com/company_olahraga-dalam-ruang_4919/
# https://www.indotrading.com/company_olahraga-luar-ruang_4920/
# https://www.indotrading.com/company_peralatanberkemah_693/
# https://www.indotrading.com/company_olahragaair_690/
# https://www.indotrading.com/company_olahraga-team_4921/
# https://www.indotrading.com/company_saranahiburan_764/
# https://www.indotrading.com/company_arang_1766/
# https://www.indotrading.com/company_jual-gas-medis-industri_7865/
# https://www.indotrading.com/company_jual-minyak-bumi_18214/
# https://www.indotrading.com/company_jual-amenities-hotel_19849/
# https://www.indotrading.com/company_jual-peralatan-dapur-komersial_7382/
# https://www.indotrading.com/company_peralatanrumahmakan_1829/
# https://www.indotrading.com/company_dompet-dan-holder_4904/
# https://www.indotrading.com/company_koper-dan-tas-travel_4900/
# https://www.indotrading.com/company_tas-bisnis_4903/
# https://www.indotrading.com/company_tas-tangan-dan-clutch_4905/
# https://www.indotrading.com/company_tas-khusus_4902/
# https://www.indotrading.com/company_mainanmodel_507/
# https://www.indotrading.com/company_jual-bola-olahraga_19602/
# https://www.indotrading.com/company_mainanbayi_501/
# https://www.indotrading.com/company_mainanedukasi_502/
# https://www.indotrading.com/company_mainanelektrik_503/
# https://www.indotrading.com/company_mainanluarruang_1326/
# https://www.indotrading.com/company_mainantiup_508/
# https://www.indotrading.com/company_daur-ulang_4942/
# https://www.indotrading.com/company_managemenlimbah_591/
# https://www.indotrading.com/company_pengolahan-air-limbah_2460/

# %%
linkProv = filterLinkProvince(category[0][1])
textProv = filterTextProvince(category[0][1])

textProv
# Out:
# ['Kepulauan Riau',
#  'Kalimantan Timur',
#  'Sumatera Barat',
#  'Banten',
#  'Bali',
#  'Sumatera Utara',
#  'Jawa Tengah',
#  'Sulawesi Utara',
#  'Aceh',
#  'Sulawesi Selatan',
#  'Jawa Barat',
#  'Jawa Timur',
#  'Riau',
#  'Kalimantan Barat',
#  'Nusa Tenggara Barat',
#  'Daerah Istimewa Yogyakarta',
#  'Sumatera Selatan',
#  'Jambi',
#  'Lampung',
#  'DKI Jakarta',
#  'Kalimantan Selatan']

# %%
linkProv
# Out:
# ['https://www.indonetwork.co.id/kepulauan-riau/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/kalimantan-timur/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/sumatera-barat/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/banten/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/bali/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/sumatera-utara/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/jawa-tengah/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/sulawesi-utara/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/aceh/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/sulawesi-selatan/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/jawa-barat/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/jawa-timur/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/riau/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/kalimantan-barat/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/nusa-tenggara-barat/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/daerah-istimewa-yogyakarta/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/sumatera-selatan/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/jambi/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/lampung/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/dki-jakarta/alat-uji-ukur/perusahaan',
#  'https://www.indonetwork.co.id/kalimantan-selatan/alat-uji-ukur/perusahaan']

# %%
df = pd.DataFrame(category[1])

df.to_csv('list_category.csv', index=False, encoding="utf-8")

# %%
print(list_company['href'])
# Out:
# https://www.indotrading.com/company_jual-ac-industri-dan-perangkatnya_7705/

# %%
content2 = simple_get(category[0][0])
soup2 = BeautifulSoup(content2, 'html.parser')
filter_city = soup.find('div', class_='theme_menu cats a')

# %%
filter_city
# Out:
# <div class="theme_menu cats a"> <div><a href="/jual-ac-industri-dan-perangkatnya/">Semua Kota</a></div> <div><a href="/jakarta/jual-ac-industri-dan-perangkatnya/">Jakarta</a></div> <div><a href="/tangerang/jual-ac-industri-dan-perangkatnya/">Tangerang</a></div> <div><a href="/medan/jual-ac-industri-dan-perangkatnya/">Medan</a></div> <div><a href="/surabaya/jual-ac-industri-dan-perangkatnya/">Surabaya</a></div> </div>

# %%
print(category[0][0])
# Out:
# https://www.indotrading.com/jual-ac-industri-dan-perangkatnya/

# %%
companyAddress =[]
companyList = []

conte = simple_get(listLink[0])
soup4 = BeautifulSoup(conte, 'html.parser')
addr = soup4.find_all('p', class_='d-flex a-center')
tempList = soup4.find_all('a', class_='span-bold fs-18 product_title pr-10')

for i in range(len(tempList)):
    companyList.append(tempList[i]['href'])
    companyAddress.append(addr[i].text)

# %%
url = linkProv[5]

for page in range(1, 200):
    if page == 1:
        newUrl = url
        company = simple_get(newUrl)
    else:
        newUrl = url +'?page=' + str(page)
        company = simple_get(newUrl)
        
    try:
        soup = BeautifulSoup(company, 'html.parser')
    except Exception:
        continue

    listItem = soup.find_all('div', class_='product-info')
    for company in listItem:
        
        try:
            membershipLvl = company.find('div', class_='freemember').text
            membershipLvl = 'Free'
        except Exception:
            continue
            
        driver = webdriver.Chrome('C:/Users/Swift3/Downloads/Scrapper/path/chromedriver')
        driver.get(newUrl)
        
        try:
            driver.find_element_by_class_name('mask-phone-button').click()
        except NoSuchElementException as exception:
            continue

        companyName = company.find('h3').text
        companyDesc = company.find('div', class_='desc').text
        temp = company.find('div', class_='seller-name')
        companyAddr = temp.find_all('div')
        companyCity = company.find('div', class_='seller-info')

        print(companyName)
        print(membershipLvl)
        print(companyDesc)
        for i in companyAddr:
            print(i.text)
        print(companyCity.find('small').text)
# Out:
# Error during requests to https://www.indonetwork.co.id/sumatera-utara/alat-uji-ukur/perusahaan?page=47 : ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
print(len(companyList))
# Out:
# 12

# %%
category[1][76]

# %%
z = 0

for i in range(1, 10):
    linkProv = filterLinkProvince(category[0][z+ i])
    textProv = filterTextProvince(category[0][z+ i])
    
    linkCompany = {}
    
    for x in range(len(textProv)):
        linkCompany[textProv[x]] = getLinkCompany(linkProv[x])

    for m in textProv:
        for l in linkCompany[m]:

            print(l)
            
    data_company = []
    phone_wa = []
    phone_temp = []

    for j in textProv:
        for k in linkCompany[j]:
            company = simple_get(k)
            try:
                soup = BeautifulSoup(company, 'html.parser')
            except Exception:
                time.sleep(1)
                try:
                    soup = BeautifulSoup(company, 'html.parser')
                except Exception:
                    time.sleep(1)
                    try:
                        soup = BeautifulSoup(company, 'html.parser')
                    except Exception:
                        print('error')
                        continue
            companyName = soup.find('h1', class_='sc-company__title').text
            membershipLvl = soup.find('span', class_='sc-company__lb').text
            companyCtgry = category[1][z + i]
            companyDesc = soup.find('div', class_='rc-company__description').text
            companyAddr = soup.find('address').text
            companyCity = soup.find('span', class_='text-capitalize').text
            companyProv = j
            linkWA = getLinkWhatsapp(k)
            time.sleep(4)
            if linkWA is not None:
                for wa in linkWA:
                    phone_temp.append(getPhoneWA(wa))
                if len(phone_temp) == 1:
                    phone_temp.append('None')
                    phone_temp.append('None')
                elif len(phone_temp) == 2:
                    phone_temp.append('None')
                elif len(phone_temp) == 4:
                    del phone_temp[3]
                elif len(phone_temp) == 5:
                    del phone_temp[3]
                    del phone_temp[4]
                elif len(phone_temp) == 6:
                    del phone_temp[3]
                    del phone_temp[4]
                    del phone_temp[5]
            else:
                phone_temp.append('None')
                phone_temp.append('None')
                phone_temp.append('None')

            data_company.append({
                'Name':companyName,
                'Membership':membershipLvl,
                'Category':companyCtgry,
                'Description':companyDesc,
                'Address':companyAddr,
                'City':companyCity,
                'Province':companyProv
            })

            phone_wa.append(phone_temp)

            print(companyName)
            print(companyCity)
            print(companyProv)
            print(phone_temp)
            print('')
            phone_temp = []
    
    tempData = data_company
    for index in range(len(data_company)):
        for number in range(len(phone_wa[index])):
            tempData[index]['telp' + str(number+1)] = phone_wa[index][number]

    
    df = pd.DataFrame(tempData)
    df.to_csv('data_company' + str(z + i + 1) + '.csv', index=False, encoding="utf-8")
    time.sleep(1)

# %%
content = simple_get('https://www.indotrading.com/mahkotamasmandirimulia')
html = BeautifulSoup(content, 'html.parser')
companyName = html.find('a', class_='mb-5 text--black text--uppercase').text
companyAddress = html.find('div', class_='mt-10').text
companyProfile = html.find('div', class_='pb-4').find('div').text
linkWA = html.find('a', class_='hidden realwa mr-0 pr-12')

print(companyName)
print(companyAddress)
print(companyProfile)
print(linkWA['href'])
# Out:
#  PT. Mahkota Mas Mandiri Mulia
# Jakarta Barat DKI Jakarta
#   Profil Perusahaan  PT. Mahkota Mas Mandiri Mulia berdiri pada tahun 1999.
# Kami menjual mesin plastik dan mesin mesin supporting untuk mesin plastik seperti :1. Chiller : Water Cooled Screw Type, Water Cooled Type, Air Cooled Screw Type, Air Cooled Type                                                   2. Crusher                                                                              3. Auto Loader   4. MTC              5. Mixer : Vertical Mixer, Horizontal Mixer, High Speed Drying Mixer 6. Hopper Dryer   7. Rack mould and many more
#                                  Selain mesin mesin supporting kami juga menyidiakan spare parts seperti :1. Screen Filter 2. Magnet Separator3. Piala 4. Tang heater5. Kontaktor, dll
#
# Kami melayani pengiriman ke seluruh daerah jabodetabek dan seluruh Indonesia. Hubungi kami untuk info lebih lanjut.
# https://api.whatsapp.com/send?phone=628111931898&text=Halo,%20Kami%20Dapat%20No%20Anda%20Dari%20Indotrading&source=&data=

# %%
df = pd.DataFrame(tempData)

df.to_csv('data_company25.csv', index=False, encoding="utf-8")
